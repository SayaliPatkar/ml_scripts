# %%
https://www.datacamp.com/tutorial/decision-tree-classification-python

https://www.kaggle.com/code/vivek468/heartattackprediction-decisiontree

https://www.kaggle.com/datasets/rashikrahmanpritom/heart-attack-analysis-prediction-dataset/data



gini index and information gain and gain ratio


decision tree, bagging classifier
https://www.kaggle.com/code/krupahs/kernel60d4792b22

# %% [markdown]
# # Heart Attack Dataset, Decision Tree, Bagging Classifier

# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %%
def make_report(gt_list, pred_list, labels, data_type="Training"):
    print("%s metrics: " % (data_type))
    print("Sample count %d" %(len(gt_list)))
    print("Percent %s accuracy %d" %(data_type, 100 * accuracy_score(gt_list, pred_list)))
    print("%s confusion metrics: " %(data_type))
    ConfusionMatrixDisplay.from_predictions(gt_list,
                                                 pred_list,
                                                 display_labels=labels,
                                                 xticks_rotation="vertical"
                                            )
    plt.tight_layout()
    plt.show()

# %%
heart_df = pd.read_csv('D:/Users/DevPatsay/pure_ml_scripts/data/heart-attack/heart.csv')
print(f"Number of Data Samples : {heart_df.shape[0]} \nNumber of Features : {heart_df.shape[1]}")
heart_df.head()
# Out:
# Number of Data Samples : 303
# Number of Features : 14
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
y = heart_df.pop("output")
X = heart_df
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state = 42)

# %% [markdown]
# ### Decision Tree Algorithm
#
# Decision tree is flowchart-like structure, where internal node represents a feature, branch represents a decision and finally leaf node represents an outcome. Considering a case where "risk of heart-attack" is predicted using 3 features: age, weight and smoking habit. Final tree may look something like this.
#
# ![Alt text](data/decision_tree.png)
#
# A decision tree is a white box type of ML algorithm. It shares internal decision-making logic, which is not available in the black box type of algorithms such as with a neural network.
#
# The time complexity of decision trees is a function of the number of records and attributes in the given data.
#
# #### Basic Idea
# 1. Select the best attribute using Attribute Selection Measures (ASM) to split the records
# 2. Make that attribute a decision node and breaks the dataset into smaller subsets
# 3. Repeat steps 1 and 2 recursively to build subtrees until
#
#     a. all the features are used up
#
#     b. clear classification is achieved
#
#     c. all the data is used up
